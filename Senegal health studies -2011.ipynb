# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# Load the dataset
health_file_path = "Resources/HNPQEXCEL.csv"

# %%
# Read the health and nutrition study results
health_metadata = pd.read_csv(health_file_path)
pd.set_option('display.max_colwidth', None)
health_metadata.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                                  Indicator Name  \
# 0    Total fertility rate (TFR) (births per woman): Q1 (lowest)
# 1             Total fertility rate (TFR) (births per woman): Q2
# 2             Total fertility rate (TFR) (births per woman): Q3
# 3             Total fertility rate (TFR) (births per woman): Q4
# 4   Total fertility rate (TFR) (births per woman): Q5 (highest)
#
#    Indicator Code  1990  1991  1992  1993  1994  1995  ...  2012  2013  2014  \
# 0  SP.DYN.TFRT.Q1   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 1  SP.DYN.TFRT.Q2   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 2  SP.DYN.TFRT.Q3   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 3  SP.DYN.TFRT.Q4   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 4  SP.DYN.TFRT.Q5   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
#
#    2015  2016  2017  2018  2019  2020  2021
# 0   5.3   NaN   NaN   NaN   NaN   NaN   NaN
# 1   5.4   NaN   NaN   NaN   NaN   NaN   NaN
# 2   5.8   NaN   NaN   NaN   NaN   NaN   NaN
# 3   5.3   NaN   NaN   NaN   NaN   NaN   NaN
# 4   4.6   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 36 columns]

# %%
# Cleanup dataset for the desired columns and indictaors
specific_columns_health_metadata = health_metadata[["Country Name","Country Code","Indicator Name","2011","2015"]] 
cleaned_health_metadata = specific_columns_health_metadata.dropna()

list_of_countries = cleaned_health_metadata["Country Name"].unique()
list_of_indicator_name = cleaned_health_metadata["Indicator Name"].unique()
list_of_quintile = ["Q1","Q2","Q3","Q4","Q5"]

# %%
list_of_countries
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Armenia',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belize', 'Benin', 'Bolivia',
#        'Bosnia and Herzegovina', 'Burkina Faso', 'Burundi', 'Cambodia',
#        'Cameroon', 'Central African Republic', 'Chad', 'Colombia',
#        'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica',
#        "Cote d'Ivoire", 'Dominican Republic', 'Egypt, Arab Rep.',
#        'El Salvador', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia, The',
#        'Georgia', 'Ghana', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'Honduras', 'India', 'Indonesia', 'Iraq',
#        'Jamaica', 'Jordan', 'Kazakhstan', 'Kenya', 'Kyrgyz Republic',
#        'Lao PDR', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali',
#        'Mauritania', 'Mexico', 'Moldova', 'Mongolia', 'Montenegro',
#        'Mozambique', 'Namibia', 'Nepal', 'Nicaragua', 'Niger', 'Nigeria',
#        'North Macedonia', 'Pakistan', 'Panama', 'Paraguay', 'Peru',
#        'Philippines', 'Rwanda', 'Sao Tome and Principe', 'Senegal',
#        'Serbia', 'Sierra Leone', 'Somalia', 'South Africa', 'St. Lucia',
#        'Sudan', 'Suriname', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo',
#        'Trinidad and Tobago', 'Tunisia', 'Turkiye', 'Turkmenistan',
#        'Uganda', 'Ukraine', 'Uruguay', 'Vietnam', 'West Bank and Gaza',
#        'Yemen, Rep.', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
list_of_indicator_name
# Out:
# array(['Antenatal care (any skilled personnel) (% of women with a birth): Q1 (lowest)',
#        'Antenatal care (any skilled personnel) (% of women with a birth): Q2',
#        'Antenatal care (any skilled personnel) (% of women with a birth): Q3',
#        'Antenatal care (any skilled personnel) (% of women with a birth): Q4',
#        'Antenatal care (any skilled personnel) (% of women with a birth): Q5 (highest)',
#        'Antenatal care (doctor) (% of women with a birth): Q1 (lowest)',
#        'Antenatal care (doctor) (% of women with a birth): Q2',
#        'Antenatal care (doctor) (% of women with a birth): Q3',
#        'Antenatal care (doctor) (% of women with a birth): Q4',
#        'Antenatal care (doctor) (% of women with a birth): Q5 (highest)',
#        'Assistance during delivery (any skilled personnel) (% of births): Q1 (lowest)',
#        'Assistance during delivery (any skilled personnel) (% of births): Q2',
#        'Assistance during delivery (any skilled personnel) (% of births): Q3',
#        'Assistance during delivery (any skilled personnel) (% of births): Q4',
#        'Assistance during delivery (any skilled personnel) (% of births): Q5 (highest)',
#        'Assistance during delivery (doctor) (% of births): Q1 (lowest)',
#        'Assistance during delivery (doctor) (% of births): Q2',
#        'Assistance during delivery (doctor) (% of births): Q3',
#        'Assistance during delivery (doctor) (% of births): Q4',
#        'Assistance during delivery (doctor) (% of births): Q5 (highest)',
#        'Completeness of birth registration (%): Q1 (lowest)',
#        'Completeness of birth registration (%): Q2',
#        'Completeness of birth registration (%): Q3',
#        'Completeness of birth registration (%): Q4',
#        'Completeness of birth registration (%): Q5 (highest)',
#        'Current use of contraception (any method) (% of married women): Q1 (lowest)',
#        'Current use of contraception (any method) (% of married women): Q2',
#        'Current use of contraception (any method) (% of married women): Q3',
#        'Current use of contraception (any method) (% of married women): Q4',
#        'Current use of contraception (any method) (% of married women): Q5 (highest)',
#        'Current use of contraception (modern method) (% of married women): Q1 (lowest)',
#        'Current use of contraception (modern method) (% of married women): Q2',
#        'Current use of contraception (modern method) (% of married women): Q3',
#        'Current use of contraception (modern method) (% of married women): Q4',
#        'Current use of contraception (modern method) (% of married women): Q5 (highest)',
#        'Infant mortality rate (per 1,000 live births): Q1 (lowest)',
#        'Infant mortality rate (per 1,000 live births): Q2',
#        'Infant mortality rate (per 1,000 live births): Q3',
#        'Infant mortality rate (per 1,000 live births): Q4',
#        'Infant mortality rate (per 1,000 live births): Q5 (highest)',
#        'People practicing open defecation (% of population): Q1 (lowest)',
#        'People practicing open defecation (% of population): Q2',
#        'People practicing open defecation (% of population): Q3',
#        'People practicing open defecation (% of population): Q4',
#        'People practicing open defecation (% of population): Q5 (highest)',
#        'People practicing open defecation, rural (% of rural population): Q1 (lowest)',
#        'People practicing open defecation, rural (% of rural population): Q2',
#        'People practicing open defecation, rural (% of rural population): Q3',
#        'People practicing open defecation, rural (% of rural population): Q4',
#        'People practicing open defecation, rural (% of rural population): Q5 (highest)',
#        'People practicing open defecation, urban (% of urban population): Q1 (lowest)',
#        'People practicing open defecation, urban (% of urban population): Q2',
#        'People practicing open defecation, urban (% of urban population): Q3',
#        'People practicing open defecation, urban (% of urban population): Q4',
#        'People practicing open defecation, urban (% of urban population): Q5 (highest)',
#        'People using at least basic drinking water services (% of  population): Q1 (lowest)',
#        'People using at least basic drinking water services (% of  population): Q2',
#        'People using at least basic drinking water services (% of  population): Q3',
#        'People using at least basic drinking water services (% of  population): Q4',
#        'People using at least basic drinking water services (% of  population): Q5 (highest)',
#        'People using at least basic drinking water services, rural (% of rural population): Q1 (lowest)',
#        'People using at least basic drinking water services, rural (% of rural population): Q2',
#        'People using at least basic drinking water services, rural (% of rural population): Q3',
#        'People using at least basic drinking water services, rural (% of rural population): Q4',
#        'People using at least basic drinking water services, rural (% of rural population): Q5 (highest)',
#        'People using at least basic drinking water services, urban (% of urban population): Q1 (lowest)',
#        'People using at least basic drinking water services, urban (% of urban population): Q2',
#        'People using at least basic drinking water services, urban (% of urban population): Q3',
#        'People using at least basic drinking water services, urban (% of urban population): Q4',
#        'People using at least basic drinking water services, urban (% of urban population): Q5 (highest)',
#        'People using at least basic sanitation services (% of  population): Q1 (lowest)',
#        'People using at least basic sanitation services (% of  population): Q2',
#        'People using at least basic sanitation services (% of  population): Q3',
#        'People using at least basic sanitation services (% of  population): Q4',
#        'People using at least basic sanitation services (% of  population): Q5 (highest)',
#        'People using at least basic sanitation services, rural (% of rural population): Q1 (lowest)',
#        'People using at least basic sanitation services, rural (% of rural population): Q2',
#        'People using at least basic sanitation services, rural (% of rural population): Q3',
#        'People using at least basic sanitation services, rural (% of rural population): Q4',
#        'People using at least basic sanitation services, rural (% of rural population): Q5 (highest)',
#        'People using at least basic sanitation services, urban (% of urban population): Q1 (lowest)',
#        'People using at least basic sanitation services, urban (% of urban population): Q2',
#        'People using at least basic sanitation services, urban (% of urban population): Q3',
#        'People using at least basic sanitation services, urban (% of urban population): Q4',
#        'People using at least basic sanitation services, urban (% of urban population): Q5 (highest)',
#        'Place of delivery (births at health facility) (% of births): Q1 (lowest)',
#        'Place of delivery (births at health facility) (% of births): Q2',
#        'Place of delivery (births at health facility) (% of births): Q3',
#        'Place of delivery (births at health facility) (% of births): Q4',
#        'Place of delivery (births at health facility) (% of births): Q5 (highest)',
#        'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q1 (lowest)',
#        'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q2',
#        'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q3',
#        'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q4',
#        'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q5 (highest)',
#        'Prevalence of diarrhea (% of children under 5): Q1 (lowest)',
#        'Prevalence of diarrhea (% of children under 5): Q2',
#        'Prevalence of diarrhea (% of children under 5): Q3',
#        'Prevalence of diarrhea (% of children under 5): Q4',
#        'Prevalence of diarrhea (% of children under 5): Q5 (highest)',
#        'Tetanus toxoid vaccination (% of live births): Q1 (lowest)',
#        'Tetanus toxoid vaccination (% of live births): Q2',
#        'Tetanus toxoid vaccination (% of live births): Q3',
#        'Tetanus toxoid vaccination (% of live births): Q4',
#        'Tetanus toxoid vaccination (% of live births): Q5 (highest)',
#        'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q1 (lowest)',
#        'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q2',
#        'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q3',
#        'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q4',
#        'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q5 (highest)',
#        'Treatment of diarrhea (either ORS or RHS) (% of children under 5): Q1 (lowest)',
#        'Treatment of diarrhea (either ORS or RHS) (% of children under 5): Q2',
#        'Treatment of diarrhea (either ORS or RHS) (% of children under 5): Q3',
#        'Treatment of diarrhea (either ORS or RHS) (% of children under 5): Q4',
#        'Treatment of diarrhea (either ORS or RHS) (% of children under 5): Q5 (highest)',
#        'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q1 (lowest)',
#        'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q2',
#        'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q3',
#        'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q4',
#        'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q5 (highest)',
#        'Under-5 mortality rate (per 1,000 live births): Q1 (lowest)',
#        'Under-5 mortality rate (per 1,000 live births): Q2',
#        'Under-5 mortality rate (per 1,000 live births): Q3',
#        'Under-5 mortality rate (per 1,000 live births): Q4',
#        'Under-5 mortality rate (per 1,000 live births): Q5 (highest)',
#        'Vaccinations (all vaccinations) (% of children ages 12-23 months): Q1 (lowest)',
#        'Vaccinations (all vaccinations) (% of children ages 12-23 months): Q2',
#        'Vaccinations (all vaccinations) (% of children ages 12-23 months): Q3',
#        'Vaccinations (all vaccinations) (% of children ages 12-23 months): Q4',
#        'Vaccinations (all vaccinations) (% of children ages 12-23 months): Q5 (highest)',
#        'Vaccinations (BCG) (% of children ages 12-23 months): Q1 (lowest)',
#        'Vaccinations (BCG) (% of children ages 12-23 months): Q2',
#        'Vaccinations (BCG) (% of children ages 12-23 months): Q3',
#        'Vaccinations (BCG) (% of children ages 12-23 months): Q4',
#        'Vaccinations (BCG) (% of children ages 12-23 months): Q5 (highest)',
#        'Vaccinations (DPT 3) (% of children ages 12-23 months): Q1 (lowest)',
#        'Vaccinations (DPT 3) (% of children ages 12-23 months): Q2',
#        'Vaccinations (DPT 3) (% of children ages 12-23 months): Q3',
#        'Vaccinations (DPT 3) (% of children ages 12-23 months): Q4',
#        'Vaccinations (DPT 3) (% of children ages 12-23 months): Q5 (highest)',
#        'Vaccinations (Measles) (% of children ages 12-23 months): Q1 (lowest)',
#        'Vaccinations (Measles) (% of children ages 12-23 months): Q2',
#        'Vaccinations (Measles) (% of children ages 12-23 months): Q3',
#        'Vaccinations (Measles) (% of children ages 12-23 months): Q4',
#        'Vaccinations (Measles) (% of children ages 12-23 months): Q5 (highest)',
#        'Vaccinations (no vaccinations) (% of children ages 12-23 months): Q1 (lowest)',
#        'Vaccinations (no vaccinations) (% of children ages 12-23 months): Q2',
#        'Vaccinations (no vaccinations) (% of children ages 12-23 months): Q3',
#        'Vaccinations (no vaccinations) (% of children ages 12-23 months): Q4',
#        'Vaccinations (no vaccinations) (% of children ages 12-23 months): Q5 (highest)',
#        'Vitamin A supplements for children (% of children ages 6-59 months): Q1 (lowest)',
#        'Vitamin A supplements for children (% of children ages 6-59 months): Q2',
#        'Vitamin A supplements for children (% of children ages 6-59 months): Q3',
#        'Vitamin A supplements for children (% of children ages 6-59 months): Q4',
#        'Vitamin A supplements for children (% of children ages 6-59 months): Q5 (highest)',
#        ' Total fertility rate (TFR) (births per woman): Q1 (lowest)',
#        ' Total fertility rate (TFR) (births per woman): Q2',
#        ' Total fertility rate (TFR) (births per woman): Q3',
#        ' Total fertility rate (TFR) (births per woman): Q4',
#        ' Total fertility rate (TFR) (births per woman): Q5 (highest)',
#        'Malnourished children (stunting, -2SD) (% of children under 5): Q1 (lowest)',
#        'Malnourished children (stunting, -2SD) (% of children under 5): Q2',
#        'Malnourished children (stunting, -2SD) (% of children under 5): Q3',
#        'Malnourished children (stunting, -2SD) (% of children under 5): Q4',
#        'Malnourished children (stunting, -2SD) (% of children under 5): Q5 (highest)',
#        'Malnourished children (stunting, -3SD) (% of children under 5): Q1 (lowest)',
#        'Malnourished children (stunting, -3SD) (% of children under 5): Q2',
#        'Malnourished children (stunting, -3SD) (% of children under 5): Q3',
#        'Malnourished children (stunting, -3SD) (% of children under 5): Q4',
#        'Malnourished children (stunting, -3SD) (% of children under 5): Q5 (highest)',
#        'Malnourished children (underweight, -2SD) (% of children under 5): Q1 (lowest)',
#        'Malnourished children (underweight, -2SD) (% of children under 5): Q2',
#        'Malnourished children (underweight, -2SD) (% of children under 5): Q3',
#        'Malnourished children (underweight, -2SD) (% of children under 5): Q4',
#        'Malnourished children (underweight, -2SD) (% of children under 5): Q5 (highest)',
#        'Malnourished children (underweight, -3SD) (% of children under 5): Q1 (lowest)',
#        'Malnourished children (underweight, -3SD) (% of children under 5): Q2',
#        'Malnourished children (underweight, -3SD) (% of children under 5): Q3',
#        'Malnourished children (underweight, -3SD) (% of children under 5): Q4',
#        'Malnourished children (underweight, -3SD) (% of children under 5): Q5 (highest)',
#        'Malnourished children (wasting, -2SD) (% of children under 5): Q1 (lowest)',
#        'Malnourished children (wasting, -2SD) (% of children under 5): Q2',
#        'Malnourished children (wasting, -2SD) (% of children under 5): Q3',
#        'Malnourished children (wasting, -2SD) (% of children under 5): Q4',
#        'Malnourished children (wasting, -2SD) (% of children under 5): Q5 (highest)',
#        'Malnourished children (wasting, -3SD) (% of children under 5): Q1 (lowest)',
#        'Malnourished children (wasting, -3SD) (% of children under 5): Q2',
#        'Malnourished children (wasting, -3SD) (% of children under 5): Q3',
#        'Malnourished children (wasting, -3SD) (% of children under 5): Q4',
#        'Malnourished children (wasting, -3SD) (% of children under 5): Q5 (highest)',
#        'Unmet need for family planning (for limiting) (% of married women): Q1 (lowest)',
#        'Unmet need for family planning (for limiting) (% of married women): Q2',
#        'Unmet need for family planning (for limiting) (% of married women): Q3',
#        'Unmet need for family planning (for limiting) (% of married women): Q4',
#        'Unmet need for family planning (for limiting) (% of married women): Q5 (highest)',
#        'Unmet need for family planning (for spacing) (% of married women): Q1 (lowest)',
#        'Unmet need for family planning (for spacing) (% of married women): Q2',
#        'Unmet need for family planning (for spacing) (% of married women): Q3',
#        'Unmet need for family planning (for spacing) (% of married women): Q4',
#        'Unmet need for family planning (for spacing) (% of married women): Q5 (highest)',
#        'Unmet need for family planning (total) (% of married women): Q1 (lowest)',
#        'Unmet need for family planning (total) (% of married women): Q2',
#        'Unmet need for family planning (total) (% of married women): Q3',
#        'Unmet need for family planning (total) (% of married women): Q4',
#        'Unmet need for family planning (total) (% of married women): Q5 (highest)',
#        'Anti-malarial drug use by pregnant women (SP/Fansidar two or more doses) (% of women with a birth): Q1 (lowest)',
#        'Anti-malarial drug use by pregnant women (SP/Fansidar two or more doses) (% of women with a birth): Q2',
#        'Anti-malarial drug use by pregnant women (SP/Fansidar two or more doses) (% of women with a birth): Q3',
#        'Anti-malarial drug use by pregnant women (SP/Fansidar two or more doses) (% of women with a birth): Q4',
#        'Anti-malarial drug use by pregnant women (SP/Fansidar two or more doses) (% of women with a birth): Q5 (highest)',
#        'Mosquito net use by children (any mosquito net) (% of children under 5): Q1 (lowest)',
#        'Mosquito net use by children (any mosquito net) (% of children under 5): Q2',
#        'Mosquito net use by children (any mosquito net) (% of children under 5): Q3',
#        'Mosquito net use by children (any mosquito net) (% of children under 5): Q4',
#        'Mosquito net use by children (any mosquito net) (% of children under 5): Q5 (highest)',
#        'Mosquito net use by children (insecticide-treated net) (% of children under 5): Q1 (lowest)',
#        'Mosquito net use by children (insecticide-treated net) (% of children under 5): Q2',
#        'Mosquito net use by children (insecticide-treated net) (% of children under 5): Q3',
#        'Mosquito net use by children (insecticide-treated net) (% of children under 5): Q4',
#        'Mosquito net use by children (insecticide-treated net) (% of children under 5): Q5 (highest)',
#        'Prevalence of children with fever (% of children under 5): Q1 (lowest)',
#        'Prevalence of children with fever (% of children under 5): Q2',
#        'Prevalence of children with fever (% of children under 5): Q3',
#        'Prevalence of children with fever (% of children under 5): Q4',
#        'Prevalence of children with fever (% of children under 5): Q5 (highest)',
#        'Treatment of fever (% of children under 5 with fever): Q1 (lowest)',
#        'Treatment of fever (% of children under 5 with fever): Q2',
#        'Treatment of fever (% of children under 5 with fever): Q3',
#        'Treatment of fever (% of children under 5 with fever): Q4',
#        'Treatment of fever (% of children under 5 with fever): Q5 (highest)',
#        'Desire to stop (limit) childbearing (% of married women): Q1 (lowest)',
#        'Desire to stop (limit) childbearing (% of married women): Q2',
#        'Desire to stop (limit) childbearing (% of married women): Q3',
#        'Desire to stop (limit) childbearing (% of married women): Q4',
#        'Desire to stop (limit) childbearing (% of married women): Q5 (highest)',
#        'Household posession of mosquito nets (any type of mosquito net) (% of households): Q1 (lowest)',
#        'Household posession of mosquito nets (any type of mosquito net) (% of households): Q2',
#        'Household posession of mosquito nets (any type of mosquito net) (% of households): Q3',
#        'Household posession of mosquito nets (any type of mosquito net) (% of households): Q4',
#        'Household posession of mosquito nets (any type of mosquito net) (% of households): Q5 (highest)',
#        'Household posession of mosquito nets (insecticide-treated net) (% of households): Q1 (lowest)',
#        'Household posession of mosquito nets (insecticide-treated net) (% of households): Q2',
#        'Household posession of mosquito nets (insecticide-treated net) (% of households): Q3',
#        'Household posession of mosquito nets (insecticide-treated net) (% of households): Q4',
#        'Household posession of mosquito nets (insecticide-treated net) (% of households): Q5 (highest)',
#        'Mean number of children ever born to women aged 40-49: Q1 (lowest)',
#        'Mean number of children ever born to women aged 40-49: Q2',
#        'Mean number of children ever born to women aged 40-49: Q3',
#        'Mean number of children ever born to women aged 40-49: Q4',
#        'Mean number of children ever born to women aged 40-49: Q5 (highest)',
#        'Median age at first marriage (women ages 25-49): Q1 (lowest)',
#        'Median age at first marriage (women ages 25-49): Q2',
#        'Median age at first marriage (women ages 25-49): Q3',
#        'Median age at first marriage (women ages 25-49): Q4',
#        'Median age at first marriage (women ages 25-49): Q5 (highest)',
#        'Median age at first sexual intercourse (women ages 25-49): Q1 (lowest)',
#        'Median age at first sexual intercourse (women ages 25-49): Q2',
#        'Median age at first sexual intercourse (women ages 25-49): Q3',
#        'Median age at first sexual intercourse (women ages 25-49): Q4',
#        'Median age at first sexual intercourse (women ages 25-49): Q5 (highest)',
#        'Median birth interval (months): Q1 (lowest)',
#        'Median birth interval (months): Q2',
#        'Median birth interval (months): Q3',
#        'Median birth interval (months): Q4',
#        'Median birth interval (months): Q5 (highest)',
#        'Mosquito net use by pregnant women (any mosquito net) (% of pregnant women): Q1 (lowest)',
#        'Mosquito net use by pregnant women (any mosquito net) (% of pregnant women): Q2',
#        'Mosquito net use by pregnant women (any mosquito net) (% of pregnant women): Q3',
#        'Mosquito net use by pregnant women (any mosquito net) (% of pregnant women): Q4',
#        'Mosquito net use by pregnant women (any mosquito net) (% of pregnant women): Q5 (highest)',
#        'Mosquito net use by pregnant women (insecticide-treated net) (% of pregnant women): Q1 (lowest)',
#        'Mosquito net use by pregnant women (insecticide-treated net) (% of pregnant women): Q2',
#        'Mosquito net use by pregnant women (insecticide-treated net) (% of pregnant women): Q3',
#        'Mosquito net use by pregnant women (insecticide-treated net) (% of pregnant women): Q4',
#        'Mosquito net use by pregnant women (insecticide-treated net) (% of pregnant women): Q5 (highest)',
#        'Teenage pregnancy and motherhood (% of women ages 15-19 who have had children or are currently pregnant): Q1 (lowest)',
#        'Teenage pregnancy and motherhood (% of women ages 15-19 who have had children or are currently pregnant): Q2',
#        'Teenage pregnancy and motherhood (% of women ages 15-19 who have had children or are currently pregnant): Q3',
#        'Teenage pregnancy and motherhood (% of women ages 15-19 who have had children or are currently pregnant): Q4',
#        'Teenage pregnancy and motherhood (% of women ages 15-19 who have had children or are currently pregnant): Q5 (highest)',
#        'Components of antenatal care (received iron tablets or syrup) (% of women with a birth): Q1 (lowest)',
#        'Components of antenatal care (received iron tablets or syrup) (% of women with a birth): Q2',
#        'Components of antenatal care (received iron tablets or syrup) (% of women with a birth): Q3',
#        'Components of antenatal care (received iron tablets or syrup) (% of women with a birth): Q4',
#        'Components of antenatal care (received iron tablets or syrup) (% of women with a birth): Q5 (highest)',
#        'Family planning messages in print (% of women): Q1 (lowest)',
#        'Family planning messages in print (% of women): Q2',
#        'Family planning messages in print (% of women): Q3',
#        'Family planning messages in print (% of women): Q4',
#        'Family planning messages in print (% of women): Q5 (highest)',
#        'Heard family planning on radio and television (% of women): Q1 (lowest)',
#        'Heard family planning on radio and television (% of women): Q2',
#        'Heard family planning on radio and television (% of women): Q3',
#        'Heard family planning on radio and television (% of women): Q4',
#        'Heard family planning on radio and television (% of women): Q5 (highest)',
#        'Knowledge of diarrhea care (% of mothers): Q1 (lowest)',
#        'Knowledge of diarrhea care (% of mothers): Q2',
#        'Knowledge of diarrhea care (% of mothers): Q3',
#        'Knowledge of diarrhea care (% of mothers): Q4',
#        'Knowledge of diarrhea care (% of mothers): Q5 (highest)',
#        'Median age at first birth (women ages 25-49): Q1 (lowest)',
#        'Median age at first birth (women ages 25-49): Q2',
#        'Median age at first birth (women ages 25-49): Q3',
#        'Median age at first birth (women ages 25-49): Q4',
#        'Median age at first birth (women ages 25-49): Q5 (highest)',
#        'Total wanted fertility rate (births per woman): Q1 (lowest)',
#        'Total wanted fertility rate (births per woman): Q2',
#        'Total wanted fertility rate (births per woman): Q3',
#        'Total wanted fertility rate (births per woman): Q4',
#        'Total wanted fertility rate (births per woman): Q5 (highest)',
#        'Vitamin A supplements for postpartum women (% of women with a birth): Q1 (lowest)',
#        'Vitamin A supplements for postpartum women (% of women with a birth): Q2',
#        'Vitamin A supplements for postpartum women (% of women with a birth): Q3',
#        'Vitamin A supplements for postpartum women (% of women with a birth): Q4',
#        'Vitamin A supplements for postpartum women (% of women with a birth): Q5 (highest)',
#        'Malnourished women (BMI is less than 18.5) (% of women): Q1 (lowest)',
#        'Malnourished women (BMI is less than 18.5) (% of women): Q2',
#        'Malnourished women (BMI is less than 18.5) (% of women): Q3',
#        'Malnourished women (BMI is less than 18.5) (% of women): Q4',
#        'Malnourished women (BMI is less than 18.5) (% of women): Q5 (highest)',
#        'Problems in accessing health care (any of the specified problems) (% of women): Q1 (lowest)',
#        'Problems in accessing health care (any of the specified problems) (% of women): Q2',
#        'Problems in accessing health care (any of the specified problems) (% of women): Q3',
#        'Problems in accessing health care (any of the specified problems) (% of women): Q4',
#        'Problems in accessing health care (any of the specified problems) (% of women): Q5 (highest)',
#        'Problems in accessing health care (distance to health facility) (% of women): Q1 (lowest)',
#        'Problems in accessing health care (distance to health facility) (% of women): Q2',
#        'Problems in accessing health care (distance to health facility) (% of women): Q3',
#        'Problems in accessing health care (distance to health facility) (% of women): Q4',
#        'Problems in accessing health care (distance to health facility) (% of women): Q5 (highest)',
#        'Problems in accessing health care (getting money for treatment) (% of women): Q1 (lowest)',
#        'Problems in accessing health care (getting money for treatment) (% of women): Q2',
#        'Problems in accessing health care (getting money for treatment) (% of women): Q3',
#        'Problems in accessing health care (getting money for treatment) (% of women): Q4',
#        'Problems in accessing health care (getting money for treatment) (% of women): Q5 (highest)',
#        'Problems in accessing health care (getting permission to go for treatment) (% of women): Q1 (lowest)',
#        'Problems in accessing health care (getting permission to go for treatment) (% of women): Q2',
#        'Problems in accessing health care (getting permission to go for treatment) (% of women): Q3',
#        'Problems in accessing health care (getting permission to go for treatment) (% of women): Q4',
#        'Problems in accessing health care (getting permission to go for treatment) (% of women): Q5 (highest)',
#        'Problems in accessing health care (not wanting to go alone) (% of women): Q1 (lowest)',
#        'Problems in accessing health care (not wanting to go alone) (% of women): Q2',
#        'Problems in accessing health care (not wanting to go alone) (% of women): Q3',
#        'Problems in accessing health care (not wanting to go alone) (% of women): Q4',
#        'Problems in accessing health care (not wanting to go alone) (% of women): Q5 (highest)',
#        'Smoking (% of women): Q1 (lowest)', 'Smoking (% of women): Q2',
#        'Smoking (% of women): Q3', 'Smoking (% of women): Q4',
#        'Smoking (% of women): Q5 (highest)'], dtype=object)

# %%
# Senegal country has all the necesity records for the given indicators
country_senegal_df = cleaned_health_metadata.loc[cleaned_health_metadata["Country Name"] == "Senegal"]


country_senegal_df.head()
# Out:
#       Country Name Country Code  \
# 70140      Senegal          SEN
# 70141      Senegal          SEN
# 70142      Senegal          SEN
# 70143      Senegal          SEN
# 70144      Senegal          SEN
#
#                                                      Indicator Name  2011  \
# 70140    Total fertility rate (TFR) (births per woman): Q1 (lowest)   7.0
# 70141             Total fertility rate (TFR) (births per woman): Q2   6.2
# 70142             Total fertility rate (TFR) (births per woman): Q3   5.0
# 70143             Total fertility rate (TFR) (births per woman): Q4   4.3
# 70144   Total fertility rate (TFR) (births per woman): Q5 (highest)   3.3
#
#        2015
# 70140   7.3
# 70141   6.2
# 70142   5.0
# 70143   4.0
# 70144   2.8

# %%
# Data to collect for each Indicator Name Quater and populate in the dataframe (open defecation)
open_defecation_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation (% of population): Q1 (lowest)",:]
open_defecation_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation (% of population): Q2",:]
open_defecation_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation (% of population): Q3",:]
open_defecation_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation (% of population): Q4",:]
open_defecation_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation (% of population): Q5 (highest)",:]

open_defecation_df = [open_defecation_Q1,open_defecation_Q2,open_defecation_Q3,open_defecation_Q4,open_defecation_Q5]

final_open_defecation_df = pd.concat(open_defecation_df)
final_open_defecation_df['Quintile'] = list_of_quintile
final_open_defecation_df
# Out:
#       Country Name Country Code  \
# 70345      Senegal          SEN
# 70346      Senegal          SEN
# 70347      Senegal          SEN
# 70348      Senegal          SEN
# 70349      Senegal          SEN
#
#                                                           Indicator Name  \
# 70345   People practicing open defecation (% of population): Q1 (lowest)
# 70346            People practicing open defecation (% of population): Q2
# 70347            People practicing open defecation (% of population): Q3
# 70348            People practicing open defecation (% of population): Q4
# 70349  People practicing open defecation (% of population): Q5 (highest)
#
#            2011      2015 Quintile
# 70345  48.47630  45.20530       Q1
# 70346  28.60964  24.46607       Q2
# 70347   8.58056   4.33532       Q3
# 70348   1.07533   0.51887       Q4
# 70349   0.10383   0.02077       Q5

# %%
# Data to collect for each Indicator Name Quater and populate in the dataframe for rural (open defecation)
open_defecation_rural_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, rural (% of rural population): Q1 (lowest)",:]
open_defecation_rural_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, rural (% of rural population): Q2",:]
open_defecation_rural_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, rural (% of rural population): Q3",:]
open_defecation_rural_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, rural (% of rural population): Q4",:]
open_defecation_rural_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, rural (% of rural population): Q5 (highest)",:]

open_defecation_rural_df = [open_defecation_rural_Q1,open_defecation_rural_Q2,open_defecation_rural_Q3,open_defecation_rural_Q4,open_defecation_rural_Q5]

final_open_defecation_rural_df = pd.concat(open_defecation_rural_df)
final_open_defecation_rural_df['Quintile'] = list_of_quintile
final_open_defecation_rural_df
# Out:
#       Country Name Country Code  \
# 70350      Senegal          SEN
# 70351      Senegal          SEN
# 70352      Senegal          SEN
# 70353      Senegal          SEN
# 70354      Senegal          SEN
#
#                                                                        Indicator Name  \
# 70350   People practicing open defecation, rural (% of rural population): Q1 (lowest)
# 70351            People practicing open defecation, rural (% of rural population): Q2
# 70352            People practicing open defecation, rural (% of rural population): Q3
# 70353            People practicing open defecation, rural (% of rural population): Q4
# 70354  People practicing open defecation, rural (% of rural population): Q5 (highest)
#
#            2011      2015 Quintile
# 70350  51.64509  49.26824       Q1
# 70351  43.57953  39.92251       Q2
# 70352  30.16549  26.56709       Q3
# 70353  15.37139   9.55869       Q4
# 70354   2.65503   0.00000       Q5

# %%
# Data to collect for each Indicator Name Quater and populate in the dataframe for urban (open defecation)
open_defecation_urban_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, urban (% of urban population): Q1 (lowest)",:]
open_defecation_urban_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, urban (% of urban population): Q2",:]
open_defecation_urban_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, urban (% of urban population): Q3",:]
open_defecation_urban_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, urban (% of urban population): Q4",:]
open_defecation_urban_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People practicing open defecation, urban (% of urban population): Q5 (highest)",:]

open_defecation_urban_df = [open_defecation_urban_Q1,open_defecation_urban_Q2,open_defecation_urban_Q3,open_defecation_urban_Q4,open_defecation_urban_Q5]

final_open_defecation_urban_df = pd.concat(open_defecation_urban_df)
final_open_defecation_urban_df['Quintile'] = list_of_quintile
final_open_defecation_urban_df
# Out:
#       Country Name Country Code  \
# 70355      Senegal          SEN
# 70356      Senegal          SEN
# 70357      Senegal          SEN
# 70358      Senegal          SEN
# 70359      Senegal          SEN
#
#                                                                        Indicator Name  \
# 70355   People practicing open defecation, urban (% of urban population): Q1 (lowest)
# 70356            People practicing open defecation, urban (% of urban population): Q2
# 70357            People practicing open defecation, urban (% of urban population): Q3
# 70358            People practicing open defecation, urban (% of urban population): Q4
# 70359  People practicing open defecation, urban (% of urban population): Q5 (highest)
#
#           2011     2015 Quintile
# 70355  8.73773  7.32870       Q1
# 70356  1.39177  1.18324       Q2
# 70357  0.68657  0.76899       Q3
# 70358  0.06334  0.03181       Q4
# 70359  0.03285  0.04669       Q5

# %%
open_defecation_agg_df = final_open_defecation_df.groupby(["Country Name"])[["2011","2015"]].agg(['mean','median','var','std','sem'])
open_defecation_agg_df
# Out:
#                    2011                                                 2015  \
#                    mean   median         var        std       sem       mean
# Country Name
# Senegal       17.369132  8.58056  433.705639  20.825601  9.313492  14.909266
#
#
#                median         var        std       sem
# Country Name
# Senegal       4.33532  387.435331  19.683377  8.802674

# %%
merged_open_defecation_df = pd.merge(pd.merge(final_open_defecation_df,final_open_defecation_rural_df,on='Quintile'),final_open_defecation_urban_df,on='Quintile')
merged_open_defecation_df
# Out:
#   Country Name_x Country Code_x  \
# 0        Senegal            SEN
# 1        Senegal            SEN
# 2        Senegal            SEN
# 3        Senegal            SEN
# 4        Senegal            SEN
#
#                                                     Indicator Name_x  \
# 0   People practicing open defecation (% of population): Q1 (lowest)
# 1            People practicing open defecation (% of population): Q2
# 2            People practicing open defecation (% of population): Q3
# 3            People practicing open defecation (% of population): Q4
# 4  People practicing open defecation (% of population): Q5 (highest)
#
#      2011_x    2015_x Quintile Country Name_y Country Code_y  \
# 0  48.47630  45.20530       Q1        Senegal            SEN
# 1  28.60964  24.46607       Q2        Senegal            SEN
# 2   8.58056   4.33532       Q3        Senegal            SEN
# 3   1.07533   0.51887       Q4        Senegal            SEN
# 4   0.10383   0.02077       Q5        Senegal            SEN
#
#                                                                  Indicator Name_y  \
# 0   People practicing open defecation, rural (% of rural population): Q1 (lowest)
# 1            People practicing open defecation, rural (% of rural population): Q2
# 2            People practicing open defecation, rural (% of rural population): Q3
# 3            People practicing open defecation, rural (% of rural population): Q4
# 4  People practicing open defecation, rural (% of rural population): Q5 (highest)
#
#      2011_y    2015_y Country Name Country Code  \
# 0  51.64509  49.26824      Senegal          SEN
# 1  43.57953  39.92251      Senegal          SEN
# 2  30.16549  26.56709      Senegal          SEN
# 3  15.37139   9.55869      Senegal          SEN
# 4   2.65503   0.00000      Senegal          SEN
#
#                                                                    Indicator Name  \
# 0   People practicing open defecation, urban (% of urban population): Q1 (lowest)
# 1            People practicing open defecation, urban (% of urban population): Q2
# 2            People practicing open defecation, urban (% of urban population): Q3
# 3            People practicing open defecation, urban (% of urban population): Q4
# 4  People practicing open defecation, urban (% of urban population): Q5 (highest)
#
#       2011     2015
# 0  8.73773  7.32870
# 1  1.39177  1.18324
# 2  0.68657  0.76899
# 3  0.06334  0.03181
# 4  0.03285  0.04669

# %%
# Plot to compare two years 2011 and 2015 (open defecation practices)
merged_open_defecation_df.plot.bar(x="Quintile", y=["2011_y","2011_x","2015_y","2015_x"])
plt.legend(["% rural population (2011)","% urban population (2011)","% rural population (2015)","% urban population (2015)"])
plt.title("Open defecation practice (% of Senegal population in 2011 and 2015)")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% of population")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %%
# Plot to compare two years 2011 (open defecation practices)
merged_open_defecation_df.plot.bar(x="Quintile", y=["2011_y","2011_x", "2011"])
plt.legend(["% rural population (2011)","% urban population (2011)","% total population (2011)"])
plt.title("Open defecation practice (% of Senegal population 2011)")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% of population")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %%
# Data to collect for each Indicator Name and populate in the dataframe (access to drinking water)
basic_drinking_water_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services (% of  population): Q1 (lowest)",:]
basic_drinking_water_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services (% of  population): Q2",:]
basic_drinking_water_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services (% of  population): Q3",:]
basic_drinking_water_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services (% of  population): Q4",:]
basic_drinking_water_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services (% of  population): Q5 (highest)",:]

basic_drinking_water_df = [basic_drinking_water_Q1,basic_drinking_water_Q2,basic_drinking_water_Q3,basic_drinking_water_Q4,basic_drinking_water_Q5]

final_basic_drinking_water_df = pd.concat(basic_drinking_water_df)
final_basic_drinking_water_df['Quintile'] = list_of_quintile
final_basic_drinking_water_df
# Out:
#       Country Name Country Code  \
# 70360      Senegal          SEN
# 70361      Senegal          SEN
# 70362      Senegal          SEN
# 70363      Senegal          SEN
# 70364      Senegal          SEN
#
#                                                                              Indicator Name  \
# 70360   People using at least basic drinking water services (% of  population): Q1 (lowest)
# 70361            People using at least basic drinking water services (% of  population): Q2
# 70362            People using at least basic drinking water services (% of  population): Q3
# 70363            People using at least basic drinking water services (% of  population): Q4
# 70364  People using at least basic drinking water services (% of  population): Q5 (highest)
#
#            2011      2015 Quintile
# 70360  43.86977  46.60958       Q1
# 70361  53.87267  58.69854       Q2
# 70362  73.45343  78.99795       Q3
# 70363  92.09299  93.63880       Q4
# 70364  97.52921  98.05809       Q5

# %%
# Data to collect for each Indicator Name and populate in the dataframe for rural (access to drinking water)
basic_drinking_water_rural_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, rural (% of rural population): Q1 (lowest)",:]
basic_drinking_water_rural_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, rural (% of rural population): Q2",:]
basic_drinking_water_rural_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, rural (% of rural population): Q3",:]
basic_drinking_water_rural_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, rural (% of rural population): Q4",:]
basic_drinking_water_rural_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, rural (% of rural population): Q5 (highest)",:]

basic_drinking_water_rural_df = [basic_drinking_water_rural_Q1,basic_drinking_water_rural_Q2,basic_drinking_water_rural_Q3,basic_drinking_water_rural_Q4,basic_drinking_water_rural_Q5]

final_basic_drinking_water_rural_df = pd.concat(basic_drinking_water_rural_df)
final_basic_drinking_water_rural_df['Quintile'] = list_of_quintile
final_basic_drinking_water_rural_df
# Out:
#       Country Name Country Code  \
# 70365      Senegal          SEN
# 70366      Senegal          SEN
# 70367      Senegal          SEN
# 70368      Senegal          SEN
# 70369      Senegal          SEN
#
#                                                                                          Indicator Name  \
# 70365   People using at least basic drinking water services, rural (% of rural population): Q1 (lowest)
# 70366            People using at least basic drinking water services, rural (% of rural population): Q2
# 70367            People using at least basic drinking water services, rural (% of rural population): Q3
# 70368            People using at least basic drinking water services, rural (% of rural population): Q4
# 70369  People using at least basic drinking water services, rural (% of rural population): Q5 (highest)
#
#            2011      2015 Quintile
# 70365  40.38710  42.20634       Q1
# 70366  48.04268  52.02639       Q2
# 70367  52.28563  57.83875       Q3
# 70368  65.02180  71.25566       Q4
# 70369  83.54440  89.35415       Q5

# %%
# Data to collect for each Indicator Name and populate in the dataframe for urban (access to drinking water)
basic_drinking_water_urban_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, urban (% of urban population): Q1 (lowest)",:]
basic_drinking_water_urban_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, urban (% of urban population): Q2",:]
basic_drinking_water_urban_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, urban (% of urban population): Q3",:]
basic_drinking_water_urban_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, urban (% of urban population): Q4",:]
basic_drinking_water_urban_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic drinking water services, urban (% of urban population): Q5 (highest)",:]

basic_drinking_water_urban_df = [basic_drinking_water_urban_Q1,basic_drinking_water_urban_Q2,basic_drinking_water_urban_Q3,basic_drinking_water_urban_Q4,basic_drinking_water_urban_Q5]

final_basic_drinking_water_urban_df = pd.concat(basic_drinking_water_urban_df)
final_basic_drinking_water_urban_df['Quintile'] = list_of_quintile
final_basic_drinking_water_urban_df
# Out:
#       Country Name Country Code  \
# 70370      Senegal          SEN
# 70371      Senegal          SEN
# 70372      Senegal          SEN
# 70373      Senegal          SEN
# 70374      Senegal          SEN
#
#                                                                                          Indicator Name  \
# 70370   People using at least basic drinking water services, urban (% of urban population): Q1 (lowest)
# 70371            People using at least basic drinking water services, urban (% of urban population): Q2
# 70372            People using at least basic drinking water services, urban (% of urban population): Q3
# 70373            People using at least basic drinking water services, urban (% of urban population): Q4
# 70374  People using at least basic drinking water services, urban (% of urban population): Q5 (highest)
#
#            2011      2015 Quintile
# 70370  72.73932  72.44643       Q1
# 70371  92.60194  92.99218       Q2
# 70372  95.12231  95.47924       Q3
# 70373  97.77946  98.18866       Q4
# 70374  98.67086  99.02849       Q5

# %%
merged_basic_drinking_water_df = pd.merge(pd.merge(final_basic_drinking_water_df,final_basic_drinking_water_rural_df,on='Quintile'),final_basic_drinking_water_urban_df,on='Quintile')
merged_basic_drinking_water_df
# Out:
#   Country Name_x Country Code_x  \
# 0        Senegal            SEN
# 1        Senegal            SEN
# 2        Senegal            SEN
# 3        Senegal            SEN
# 4        Senegal            SEN
#
#                                                                        Indicator Name_x  \
# 0   People using at least basic drinking water services (% of  population): Q1 (lowest)
# 1            People using at least basic drinking water services (% of  population): Q2
# 2            People using at least basic drinking water services (% of  population): Q3
# 3            People using at least basic drinking water services (% of  population): Q4
# 4  People using at least basic drinking water services (% of  population): Q5 (highest)
#
#      2011_x    2015_x Quintile Country Name_y Country Code_y  \
# 0  43.86977  46.60958       Q1        Senegal            SEN
# 1  53.87267  58.69854       Q2        Senegal            SEN
# 2  73.45343  78.99795       Q3        Senegal            SEN
# 3  92.09299  93.63880       Q4        Senegal            SEN
# 4  97.52921  98.05809       Q5        Senegal            SEN
#
#                                                                                    Indicator Name_y  \
# 0   People using at least basic drinking water services, rural (% of rural population): Q1 (lowest)
# 1            People using at least basic drinking water services, rural (% of rural population): Q2
# 2            People using at least basic drinking water services, rural (% of rural population): Q3
# 3            People using at least basic drinking water services, rural (% of rural population): Q4
# 4  People using at least basic drinking water services, rural (% of rural population): Q5 (highest)
#
#      2011_y    2015_y Country Name Country Code  \
# 0  40.38710  42.20634      Senegal          SEN
# 1  48.04268  52.02639      Senegal          SEN
# 2  52.28563  57.83875      Senegal          SEN
# 3  65.02180  71.25566      Senegal          SEN
# 4  83.54440  89.35415      Senegal          SEN
#
#                                                                                      Indicator Name  \
# 0   People using at least basic drinking water services, urban (% of urban population): Q1 (lowest)
# 1            People using at least basic drinking water services, urban (% of urban population): Q2
# 2            People using at least basic drinking water services, urban (% of urban population): Q3
# 3            People using at least basic drinking water services, urban (% of urban population): Q4
# 4  People using at least basic drinking water services, urban (% of urban population): Q5 (highest)
#
#        2011      2015
# 0  72.73932  72.44643
# 1  92.60194  92.99218
# 2  95.12231  95.47924
# 3  97.77946  98.18866
# 4  98.67086  99.02849

# %%
# Plot to compare two years 2011 and 2015 (basic drinking water)
merged_basic_drinking_water_df.plot.bar(x="Quintile", y=["2011_y","2011","2015_y","2015"])
plt.legend(["% rural population (2011)","% urban population (2011)","% rural population (2015)","% urban population (2015)"])
plt.title("Access to basic drinking water (% of Senegal population in 2011 and 2015)")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% of population")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %%
# Plot to compare 2011 (basic drinking water)
merged_basic_drinking_water_df.plot.bar(x="Quintile", y=["2011_y","2011_x", "2011"])
plt.legend(["% rural population (2011)","% urban population (2011)","% total population (2011)"])
plt.title("Access to basic drinking water (% of Senegal population 2011)")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% of population")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %%
# Data to collect for each Indicator Name and populate in the dataframe (access to basic sanitation services)
basic_sanitation_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services (% of  population): Q1 (lowest)",:]
basic_sanitation_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services (% of  population): Q2",:]
basic_sanitation_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services (% of  population): Q3",:]
basic_sanitation_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services (% of  population): Q4",:]
basic_sanitation_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services (% of  population): Q5 (highest)",:]

basic_sanitation_df = [basic_sanitation_Q1,basic_sanitation_Q2,basic_sanitation_Q3,basic_sanitation_Q4,basic_sanitation_Q5]

final_basic_sanitation_df = pd.concat(basic_sanitation_df)
final_basic_sanitation_df['Quintile'] = list_of_quintile
final_basic_sanitation_df
# Out:
#       Country Name Country Code  \
# 70375      Senegal          SEN
# 70376      Senegal          SEN
# 70377      Senegal          SEN
# 70378      Senegal          SEN
# 70379      Senegal          SEN
#
#                                                                          Indicator Name  \
# 70375   People using at least basic sanitation services (% of  population): Q1 (lowest)
# 70376            People using at least basic sanitation services (% of  population): Q2
# 70377            People using at least basic sanitation services (% of  population): Q3
# 70378            People using at least basic sanitation services (% of  population): Q4
# 70379  People using at least basic sanitation services (% of  population): Q5 (highest)
#
#            2011      2015 Quintile
# 70375  11.82889  10.81114       Q1
# 70376  27.90670  30.07859       Q2
# 70377  53.55843  59.16003       Q3
# 70378  63.21721  66.13861       Q4
# 70379  81.74692  83.45652       Q5

# %%
# Data to collect for each Indicator Name and populate in the dataframe for rural (access to basic sanitation services)
basic_sanitation_rural_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, rural (% of rural population): Q1 (lowest)",:]
basic_sanitation_rural_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, rural (% of rural population): Q2",:]
basic_sanitation_rural_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, rural (% of rural population): Q3",:]
basic_sanitation_rural_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, rural (% of rural population): Q4",:]
basic_sanitation_rural_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, rural (% of rural population): Q5 (highest)",:]

basic_sanitation_rural_df = [basic_sanitation_rural_Q1,basic_sanitation_rural_Q2,basic_sanitation_rural_Q3,basic_sanitation_rural_Q4,basic_sanitation_rural_Q5]

final_basic_sanitation_rural_df = pd.concat(basic_sanitation_rural_df)
final_basic_sanitation_rural_df['Quintile'] = list_of_quintile
final_basic_sanitation_rural_df
# Out:
#       Country Name Country Code  \
# 70380      Senegal          SEN
# 70381      Senegal          SEN
# 70382      Senegal          SEN
# 70383      Senegal          SEN
# 70384      Senegal          SEN
#
#                                                                                      Indicator Name  \
# 70380   People using at least basic sanitation services, rural (% of rural population): Q1 (lowest)
# 70381            People using at least basic sanitation services, rural (% of rural population): Q2
# 70382            People using at least basic sanitation services, rural (% of rural population): Q3
# 70383            People using at least basic sanitation services, rural (% of rural population): Q4
# 70384  People using at least basic sanitation services, rural (% of rural population): Q5 (highest)
#
#            2011      2015 Quintile
# 70380   8.92191   7.03861       Q1
# 70381  16.45270  16.67629       Q2
# 70382  26.67186  28.56468       Q3
# 70383  47.85738  53.83990       Q4
# 70384  74.77838  81.91372       Q5

# %%
# Data to collect for each Indicator Name and populate in the dataframe for urban (access to basic sanitation services)
basic_sanitation_urban_Q1 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, urban (% of urban population): Q1 (lowest)",:]
basic_sanitation_urban_Q2 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, urban (% of urban population): Q2",:]
basic_sanitation_urban_Q3 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, urban (% of urban population): Q3",:]
basic_sanitation_urban_Q4 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, urban (% of urban population): Q4",:]
basic_sanitation_urban_Q5 = country_senegal_df.loc[country_senegal_df["Indicator Name"] == "People using at least basic sanitation services, urban (% of urban population): Q5 (highest)",:]

basic_sanitation_urban_df = [basic_sanitation_urban_Q1,basic_sanitation_urban_Q2,basic_sanitation_urban_Q3,basic_sanitation_urban_Q4,basic_sanitation_urban_Q5]

final_basic_sanitation_urban_df = pd.concat(basic_sanitation_urban_df)
final_basic_sanitation_urban_df['Quintile'] = list_of_quintile
final_basic_sanitation_urban_df
# Out:
#       Country Name Country Code  \
# 70385      Senegal          SEN
# 70386      Senegal          SEN
# 70387      Senegal          SEN
# 70388      Senegal          SEN
# 70389      Senegal          SEN
#
#                                                                                      Indicator Name  \
# 70385   People using at least basic sanitation services, urban (% of urban population): Q1 (lowest)
# 70386            People using at least basic sanitation services, urban (% of urban population): Q2
# 70387            People using at least basic sanitation services, urban (% of urban population): Q3
# 70388            People using at least basic sanitation services, urban (% of urban population): Q4
# 70389  People using at least basic sanitation services, urban (% of urban population): Q5 (highest)
#
#            2011      2015 Quintile
# 70385  44.33269  45.54634       Q1
# 70386  55.98944  57.94116       Q2
# 70387  60.61757  62.25476       Q3
# 70388  73.53963  74.99107       Q4
# 70389  88.75925  89.40285       Q5

# %%
merged_basic_sanitation_df = pd.merge(pd.merge(final_basic_sanitation_df,final_basic_sanitation_rural_df,on='Quintile'),final_basic_sanitation_urban_df,on='Quintile')
merged_basic_sanitation_df
# Out:
#   Country Name_x Country Code_x  \
# 0        Senegal            SEN
# 1        Senegal            SEN
# 2        Senegal            SEN
# 3        Senegal            SEN
# 4        Senegal            SEN
#
#                                                                    Indicator Name_x  \
# 0   People using at least basic sanitation services (% of  population): Q1 (lowest)
# 1            People using at least basic sanitation services (% of  population): Q2
# 2            People using at least basic sanitation services (% of  population): Q3
# 3            People using at least basic sanitation services (% of  population): Q4
# 4  People using at least basic sanitation services (% of  population): Q5 (highest)
#
#      2011_x    2015_x Quintile Country Name_y Country Code_y  \
# 0  11.82889  10.81114       Q1        Senegal            SEN
# 1  27.90670  30.07859       Q2        Senegal            SEN
# 2  53.55843  59.16003       Q3        Senegal            SEN
# 3  63.21721  66.13861       Q4        Senegal            SEN
# 4  81.74692  83.45652       Q5        Senegal            SEN
#
#                                                                                Indicator Name_y  \
# 0   People using at least basic sanitation services, rural (% of rural population): Q1 (lowest)
# 1            People using at least basic sanitation services, rural (% of rural population): Q2
# 2            People using at least basic sanitation services, rural (% of rural population): Q3
# 3            People using at least basic sanitation services, rural (% of rural population): Q4
# 4  People using at least basic sanitation services, rural (% of rural population): Q5 (highest)
#
#      2011_y    2015_y Country Name Country Code  \
# 0   8.92191   7.03861      Senegal          SEN
# 1  16.45270  16.67629      Senegal          SEN
# 2  26.67186  28.56468      Senegal          SEN
# 3  47.85738  53.83990      Senegal          SEN
# 4  74.77838  81.91372      Senegal          SEN
#
#                                                                                  Indicator Name  \
# 0   People using at least basic sanitation services, urban (% of urban population): Q1 (lowest)
# 1            People using at least basic sanitation services, urban (% of urban population): Q2
# 2            People using at least basic sanitation services, urban (% of urban population): Q3
# 3            People using at least basic sanitation services, urban (% of urban population): Q4
# 4  People using at least basic sanitation services, urban (% of urban population): Q5 (highest)
#
#        2011      2015
# 0  44.33269  45.54634
# 1  55.98944  57.94116
# 2  60.61757  62.25476
# 3  73.53963  74.99107
# 4  88.75925  89.40285

# %%
# Plot to compare two years 2011 and 2015 (basic sanitation services)
merged_basic_sanitation_df.plot.bar(x="Quintile", y=["2011_y","2011","2015_y","2015"])
plt.legend(["% rural population (2011)","% urban population (2011)","% rural population (2015)","% urban population (2015)"])
plt.title("Access to basic sanitation services (% of Senegal population in 2011 and 2015)")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% of population")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %%
# Plot to compare  2011 (basic sanitation services)
merged_basic_sanitation_df.plot.bar(x="Quintile", y=["2011_y","2011_x", "2011"])
plt.legend(["% rural population (2011)","% urban population (2011)","% total population (2011)"])
plt.title("Access to basic sanitation services (% of Senegal population 2011)")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% of population")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %%
# Define the other data indicators

indicators_ARI_prevalance = ['Prevalence of acute respiratory infection (ARI) (% of children under 5): Q1 (lowest)',
              'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q2',
              'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q3',
              'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q4',
              'Prevalence of acute respiratory infection (ARI) (% of children under 5): Q5 (highest)']

indicators_diarrhea_prevalance  =['Prevalence of diarrhea (% of children under 5): Q1 (lowest)',
              'Prevalence of diarrhea (% of children under 5): Q2',
              'Prevalence of diarrhea (% of children under 5): Q3',
              'Prevalence of diarrhea (% of children under 5): Q4',
              'Prevalence of diarrhea (% of children under 5): Q5 (highest)']

indicators_ARI_treatment = ['Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q1 (lowest)',
              'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q2',
              'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q3',
              'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q4',
              'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q5 (highest)']

indicators_diarrhea_treatment = ['Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q1 (lowest)',
              'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q2',
              'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q3',
              'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q4',
              'Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q5 (highest)']

mortality_indicator = ['Under-5 mortality rate (per 1,000 live births): Q1 (lowest)',
              'Under-5 mortality rate (per 1,000 live births): Q2',
              'Under-5 mortality rate (per 1,000 live births): Q3',
              'Under-5 mortality rate (per 1,000 live births): Q4',
              'Under-5 mortality rate (per 1,000 live births): Q5 (highest)']

# %%
ARI_prevalance_indicator_df = country_senegal_df[country_senegal_df["Indicator Name"].isin(indicators_ARI_prevalance)]

ARI_prevalance_indicator_df = ARI_prevalance_indicator_df.reset_index(drop=True)


ARI_prevalance_indicator_df['Quintiles'] = list_of_quintile


ARI_prevalance_indicator_df= ARI_prevalance_indicator_df.set_index("Quintiles").drop(['Country Name', 'Country Code'], axis=1)

ARI_prevalance_indicator_df
# Out:
#                                                                                   Indicator Name  \
# Quintiles
# Q1          Prevalence of acute respiratory infection (ARI) (% of children under 5): Q1 (lowest)
# Q2                   Prevalence of acute respiratory infection (ARI) (% of children under 5): Q2
# Q3                   Prevalence of acute respiratory infection (ARI) (% of children under 5): Q3
# Q4                   Prevalence of acute respiratory infection (ARI) (% of children under 5): Q4
# Q5         Prevalence of acute respiratory infection (ARI) (% of children under 5): Q5 (highest)
#
#            2011  2015
# Quintiles
# Q1          4.7   4.7
# Q2          3.1   3.5
# Q3          4.9   2.6
# Q4          7.3   3.9
# Q5          7.8   2.2

# %%
ARI_treatment_indicator_df = country_senegal_df[country_senegal_df["Indicator Name"].isin(indicators_ARI_treatment)]

ARI_treatment_indicator_df = ARI_treatment_indicator_df.reset_index(drop=True)
ARI_treatment_indicator_df = ARI_treatment_indicator_df.drop(['Country Name','Country Code'], axis=1)

#No record find for this indicator so using and assumpution to plot a chart
hardcoded_record_dict = {'Indicator Name': 'Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q5 (highest)',
                                  '2011': 0.0,
                                  '2015': 0.0
                                  }
hardcoded_record_df = pd.DataFrame(hardcoded_record_dict, index=[4])

ARI_treatment_indicator_df = pd.concat([ARI_treatment_indicator_df,hardcoded_record_df])
                            
ARI_treatment_indicator_df['Quintiles'] = list_of_quintile


ARI_treatment_indicator_df= ARI_treatment_indicator_df.set_index("Quintiles")

ARI_treatment_indicator_df
# Out:
#                                                                                                             Indicator Name  \
# Quintiles
# Q1          Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q1 (lowest)
# Q2                   Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q2
# Q3                   Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q3
# Q4                   Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q4
# Q5         Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q5 (highest)
#
#            2011  2015
# Quintiles
# Q1         38.6  49.0
# Q2         52.5  64.4
# Q3         61.1  49.4
# Q4         55.2  52.5
# Q5          0.0   0.0

# %%
diarrhea_prevalance_indicator_df = country_senegal_df[country_senegal_df["Indicator Name"].isin(indicators_diarrhea_prevalance)]

diarrhea_prevalance_indicator_df = diarrhea_prevalance_indicator_df.reset_index(drop=True)

diarrhea_prevalance_indicator_df['Quintiles'] = list_of_quintile


diarrhea_prevalance_indicator_df= diarrhea_prevalance_indicator_df.set_index("Quintiles").drop(['Country Name', 'Country Code'], axis=1)

diarrhea_prevalance_indicator_df
# Out:
#                                                          Indicator Name  2011  \
# Quintiles
# Q1          Prevalence of diarrhea (% of children under 5): Q1 (lowest)  25.5
# Q2                   Prevalence of diarrhea (% of children under 5): Q2  23.6
# Q3                   Prevalence of diarrhea (% of children under 5): Q3  24.6
# Q4                   Prevalence of diarrhea (% of children under 5): Q4  31.9
# Q5         Prevalence of diarrhea (% of children under 5): Q5 (highest)  24.6
#
#            2015
# Quintiles
# Q1         30.7
# Q2         24.1
# Q3         20.9
# Q4         23.0
# Q5         14.3

# %%
diarrhea_treatment_indicator_df = country_senegal_df[country_senegal_df["Indicator Name"].isin(indicators_diarrhea_treatment)]

diarrhea_treatment_indicator_df = diarrhea_treatment_indicator_df.reset_index(drop=True)

diarrhea_treatment_indicator_df['Quintiles'] = list_of_quintile


diarrhea_treatment_indicator_df= diarrhea_treatment_indicator_df.set_index("Quintiles").drop(['Country Name','Country Code'], axis=1)

diarrhea_treatment_indicator_df
# Out:
#                                                                                        Indicator Name  \
# Quintiles
# Q1          Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q1 (lowest)
# Q2                   Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q2
# Q3                   Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q3
# Q4                   Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q4
# Q5         Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q5 (highest)
#
#            2011  2015
# Quintiles
# Q1         47.9  27.2
# Q2         54.6  22.3
# Q3         45.7  28.0
# Q4         43.4  22.0
# Q5         39.1  39.2

# %%
under_five_mortality_indicator_df = country_senegal_df[country_senegal_df["Indicator Name"].isin(mortality_indicator)]

under_five_mortality_indicator_df = under_five_mortality_indicator_df.reset_index(drop=True)

under_five_mortality_indicator_df['Quintiles'] = list_of_quintile


under_five_mortality_indicator_df= under_five_mortality_indicator_df.set_index("Quintiles").drop(['Country Name', 'Country Code'], axis=1)

under_five_mortality_indicator_df
# Out:
#                                                          Indicator Name  \
# Quintiles
# Q1          Under-5 mortality rate (per 1,000 live births): Q1 (lowest)
# Q2                   Under-5 mortality rate (per 1,000 live births): Q2
# Q3                   Under-5 mortality rate (per 1,000 live births): Q3
# Q4                   Under-5 mortality rate (per 1,000 live births): Q4
# Q5         Under-5 mortality rate (per 1,000 live births): Q5 (highest)
#
#             2011  2015
# Quintiles
# Q1         119.0  87.0
# Q2          94.0  77.0
# Q3          81.0  65.0
# Q4          69.0  53.0
# Q5          54.0  37.0

# %%
ARI_merged_df = pd.merge(ARI_prevalance_indicator_df, ARI_treatment_indicator_df, on = ["Quintiles"])

ARI_merged_df
# Out:
#                                                                                 Indicator Name_x  \
# Quintiles
# Q1          Prevalence of acute respiratory infection (ARI) (% of children under 5): Q1 (lowest)
# Q2                   Prevalence of acute respiratory infection (ARI) (% of children under 5): Q2
# Q3                   Prevalence of acute respiratory infection (ARI) (% of children under 5): Q3
# Q4                   Prevalence of acute respiratory infection (ARI) (% of children under 5): Q4
# Q5         Prevalence of acute respiratory infection (ARI) (% of children under 5): Q5 (highest)
#
#            2011_x  2015_x  \
# Quintiles
# Q1            4.7     4.7
# Q2            3.1     3.5
# Q3            4.9     2.6
# Q4            7.3     3.9
# Q5            7.8     2.2
#
#                                                                                                           Indicator Name_y  \
# Quintiles
# Q1          Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q1 (lowest)
# Q2                   Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q2
# Q3                   Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q3
# Q4                   Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q4
# Q5         Treatment of acute respiratory infection (ARI) (% of children under 5 taken to a health provider): Q5 (highest)
#
#            2011_y  2015_y
# Quintiles
# Q1           38.6    49.0
# Q2           52.5    64.4
# Q3           61.1    49.4
# Q4           55.2    52.5
# Q5            0.0     0.0

# %%
# ARI Prevalance and Treatment rate in % of Children under 5 in Senegal in 2011 and 2015
ARI_merged_df.plot.bar(y=["2011_x","2011_y", "2015_x","2015_y"])
plt.legend(["ARI prevalance (% of children under 5) in 2011","ARI treatment (% of children under 5) in 2011","ARI prevalance (% of children under 5) in 2015","ARI treatment (% of children under 5) in 2015"])
plt.title("ARI Prevalance and Treatment rate in % of Children under 5 in Senegal in 2011 and 2015")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% of Children under 5")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %%
# Diarrhea Prevalance and Treatment rate in % of Children under 5 in Senegal 2011 and 2015
diarrhea_merged_df = pd.merge(diarrhea_prevalance_indicator_df, diarrhea_treatment_indicator_df, on = ["Quintiles"])

diarrhea_merged_df
# Out:
#                                                        Indicator Name_x  \
# Quintiles
# Q1          Prevalence of diarrhea (% of children under 5): Q1 (lowest)
# Q2                   Prevalence of diarrhea (% of children under 5): Q2
# Q3                   Prevalence of diarrhea (% of children under 5): Q3
# Q4                   Prevalence of diarrhea (% of children under 5): Q4
# Q5         Prevalence of diarrhea (% of children under 5): Q5 (highest)
#
#            2011_x  2015_x  \
# Quintiles
# Q1           25.5    30.7
# Q2           23.6    24.1
# Q3           24.6    20.9
# Q4           31.9    23.0
# Q5           24.6    14.3
#
#                                                                                      Indicator Name_y  \
# Quintiles
# Q1          Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q1 (lowest)
# Q2                   Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q2
# Q3                   Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q3
# Q4                   Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q4
# Q5         Treatment of diarrhea (ORS, RHS or increased fluids) (% of children under 5): Q5 (highest)
#
#            2011_y  2015_y
# Quintiles
# Q1           47.9    27.2
# Q2           54.6    22.3
# Q3           45.7    28.0
# Q4           43.4    22.0
# Q5           39.1    39.2

# %%
# Diarrhea Prevalance and Treatment rate in % of Children under 5 in Senegal 2011 and 2015
diarrhea_merged_df.plot.bar(y=["2011_x","2011_y", "2015_x","2015_y"])
plt.legend(["Diarrhea prevalance (% of children under 5) in 2011","Diarrhea treatment (% of children under 5) in 2011","Diarrhea prevalance (% of children under 5) in 2015","Diarrhea treatment (% of children under 5) in 2015"])
plt.title("Diarrhea Prevalance and Treatment rate in % of Children under 5 in Senegal in 2011 and 2015")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% of Children under 5")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %%
# % of Mortality for Children under 5 (per 1000 live births) in Senegal 2011 and 2015
under_five_mortality_indicator_df.plot.bar(y=["2011","2015"])
plt.legend(["2011","2015"])
plt.title("% of Mortality for Children under 5 (per 1000 live births) in Senegal in 2011 and 2015")
plt.xlabel("Data per Qunitiles")
plt.ylabel("% Under-5 mortality rate (per 1,000 live births)")
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.show()
plt.close()

# %% [markdown]
# # Health Data Analysis in Senegal
#
# This Jupyter Notebook performs an analysis of health indicators in Senegal, focusing on open defecation, access to drinking water, access to basic sanitation services, and child health indicators. The analysis includes both descriptive statistics and comparative analysis between different years and quintiles.

# %% [markdown]
# ## Data Description
#
# The dataset used in this analysis contains health and nutrition data for Senegal, including information on open defecation, access to clean water, access to sanitation services, and child health indicators. The dataset covers multiple years and quintiles.

# %% [markdown]
# ## Descriptive Analysis
#
# ### Open Defecation
#
# We analyze the percentage of the population practicing open defecation in Senegal, broken down by quintiles and across different years (2011 and 2015).
#
# ### Access to Drinking Water
#
# We examine the percentage of the population with access to basic drinking water services, both for rural and urban areas. The analysis covers multiple quintiles and includes data for 2011 and 2015.
#
# ### Access to Basic Sanitation Services
#
# We investigate the percentage of the population with access to basic sanitation services in Senegal. The analysis considers rural and urban areas, various quintiles, and data from 2011 and 2015.
#
# ### Child Health Indicators
#
# We assess various child health indicators, including the prevalence of acute respiratory infection (ARI), diarrhea prevalence, diarrhea treatment, and under-five mortality rate. The analysis involves comparing these indicators across quintiles for the years 2011 and 2015.

# %% [markdown]
# ## Comparative Analysis
#
# ### Open Defecation
#
# In 2015, we observe a significant decrease in the percentage of the population practicing open defecation across all quintiles compared to 2011. Quintile 5 (highest) consistently has the lowest open defecation rates.
#
# ### Access to Drinking Water
#
# Access to basic drinking water services has improved from 2011 to 2015 for both rural and urban populations. Quintile 1 (lowest) experiences the most substantial improvements.
#
# ### Access to Basic Sanitation Services
#
# Senegal has made progress in providing basic sanitation services, with notable improvements in urban areas. However, rural areas, especially in lower quintiles, still lag behind in access to sanitation services.
#
# ### Child Health Indicators
#
# The prevalence of acute respiratory infection (ARI) among children under 5 has decreased in 2015 compared to 2011. A similar trend is observed for diarrhea prevalence. However, ARI treatment rates remain low in the highest quintile.
#
# The under-five mortality rate has seen an overall decrease, reflecting improvements in child health in Senegal.
